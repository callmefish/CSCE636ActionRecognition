# %%
import os
import csv
import matplotlib.pyplot as plt


file1 = 'record/spatial_497_3/rgb_test.csv'

test_loss_3 = []
test_acc_3 = []
with open(file1, 'r') as f:
    reader = csv.reader(f)
    # 一行一行读取CSV文件，记录数值
    i = 0
    for row in reader:
        if i < 1:
            i += 1
            continue
        else:
            test_loss_3.append(round(float(row[2]), 6))
            test_acc_3.append(round(float(row[3])*0.01, 6))
f.close()

file2 = 'record/spatial_497_3/rgb_train.csv'
train_loss_3 = []
train_acc_3 = []
with open(file2, 'r') as f:
    reader = csv.reader(f)
    # 一行一行读取CSV文件，记录数值
    i = 0
    for row in reader:
        if i < 1:
            i += 1
            continue
        else:
            train_loss_3.append(round(float(row[3]), 6))
            train_acc_3.append(round(float(row[4])*0.01, 6))
f.close()

# %%
file3 = 'record/spatial_497_3_16_new/rgb_test.csv'

test_loss_4 = []
test_acc_4 = []
with open(file3, 'r') as f:
    reader = csv.reader(f)
    # 一行一行读取CSV文件，记录数值
    i = 0
    for row in reader:
        if i < 1:
            i += 1
            continue
        else:
            test_loss_4.append(round(float(row[2]), 6))
            test_acc_4.append(round(float(row[3])*0.01, 6))
f.close()

file4 = 'record/spatial_497_3_16_new/rgb_train.csv'
train_loss_4 = []
train_acc_4 = []
with open(file4, 'r') as f:
    reader = csv.reader(f)
    # 一行一行读取CSV文件，记录数值
    i = 0
    for row in reader:
        if i < 1:
            i += 1
            continue
        else:
            train_loss_4.append(round(float(row[3]), 6))
            train_acc_4.append(round(float(row[4])*0.01, 6))
f.close()

# %%
file5 = 'record/spatial_497_3_25/rgb_test.csv'

test_loss_5 = []
test_acc_5 = []
with open(file5, 'r') as f:
    reader = csv.reader(f)
    # 一行一行读取CSV文件，记录数值
    i = 0
    for row in reader:
        if i < 1:
            i += 1
            continue
        else:
            test_loss_5.append(round(float(row[2]), 6))
            test_acc_5.append(round(float(row[3])*0.01, 6))
f.close()

file6 = 'record/spatial_497_3_25/rgb_train.csv'
train_loss_5 = []
train_acc_5 = []
with open(file6, 'r') as f:
    reader = csv.reader(f)
    # 一行一行读取CSV文件，记录数值
    i = 0
    for row in reader:
        if i < 1:
            i += 1
            continue
        else:
            train_loss_5.append(round(float(row[3]), 6))
            train_acc_5.append(round(float(row[4])*0.01, 6))
f.close()

# %%
file7 = 'record/spatial/rgb_test.csv'

test_loss_6 = []
test_acc_6 = []
with open(file7, 'r') as f:
    reader = csv.reader(f)
    # 一行一行读取CSV文件，记录数值
    i = 0
    for row in reader:
        if i < 1:
            i += 1
            continue
        else:
            test_loss_6.append(round(float(row[2]), 6))
            test_acc_6.append(round(float(row[3])*0.01, 6))
f.close()

file8 = 'record/spatial_497_3_25/rgb_train.csv'
train_loss_6 = []
train_acc_6 = []
with open(file8, 'r') as f:
    reader = csv.reader(f)
    # 一行一行读取CSV文件，记录数值
    i = 0
    for row in reader:
        if i < 1:
            i += 1
            continue
        else:
            train_loss_6.append(round(float(row[3]), 6))
            train_acc_6.append(round(float(row[4])*0.01, 6))
f.close()

# %%
plt.figure()
plt.plot(train_loss_3, label='BZ=8')
plt.plot(train_loss_4, label='BZ=16')
plt.plot(train_loss_5, label='BZ=25')
plt.plot(train_loss_6, label='BZ=64')
# plt.ylim(0, int(max(Loss)) + 1)
plt.title("TSN - 3 frame - Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")

plt.legend()
plt.savefig("TSN - 3 frame - Training Loss.png")
plt.show()

plt.figure()
plt.plot(test_loss_3, label='BZ=8')
plt.plot(test_loss_4, label='BZ=16')
plt.plot(test_loss_5, label='BZ=25')
plt.plot(test_loss_6, label='BZ=64')
# plt.ylim(0, int(max(Loss)) + 1)
plt.title("TSN - 3 frame - Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.ylim(0, 10)
plt.legend()
plt.savefig("TSN - 3 frame - Validation Loss.png")
plt.show()

plt.figure()
plt.plot(train_acc_3, label='BZ=8')
plt.plot(train_acc_4, label='BZ=16')
plt.plot(train_acc_5, label='BZ=25')
plt.plot(train_acc_6, label='BZ=64')
# plt.ylim(0, int(max(Loss)) + 1)
plt.title("TSN - 3 frame - Trainging Acc")
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend()
plt.savefig("TSN - 3 frame - Trainging ACC.png")
plt.show()

plt.figure()
plt.plot(test_acc_3, label='BZ=8')
plt.plot(test_acc_4, label='BZ=16')
plt.plot(test_acc_5, label='BZ=25')
plt.plot(test_acc_6, label='BZ=64')
# plt.ylim(0, int(max(Loss)) + 1)
plt.title("TSN - 3 frame - Validation Acc")
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.legend()
plt.savefig("TSN - 3 frame - Validation ACC.png")
plt.show()

# %%
run average_fusion.py
# Out:
# ==> (Training video, Validation video):( 373 124 )
# ==> sampling testing frames
# ==> Training data : 3730 frames
# torch.Size([3, 224, 224])
# ==> Validation data : 2356 frames
# torch.Size([3, 224, 224])
# [tensor(89.5161)]

# %%
run create_txt.py

# %%
run save_pickle.py

# %%
run spatial_cnn.py
# Out:
# Namespace(batch_size=24, epochs=1, evaluate=False, lr=0.001, resume='', start_epoch=0)
# ==> (Training video, Validation video):( 357 118 )
# ==> sampling testing frames
# ==> Training data : 3570 frames
# torch.Size([3, 224, 224])
# ==> Validation data : 2224 frames
# torch.Size([3, 224, 224])
# ==> Build model and setup loss and optimizer
#   0%|          | 0/15 [00:00<?, ?it/s]
# ==> Epoch:[0/1][training stage]
#   7%|▋         | 1/15 [00:03<00:49,  3.53s/it]
#
#
#
#
#  13%|█▎        | 2/15 [00:06<00:43,  3.35s/it]
#
#
#
#
#  20%|██        | 3/15 [00:09<00:38,  3.18s/it]
#
#
#
#
#  27%|██▋       | 4/15 [00:12<00:33,  3.05s/it]
#
#
#
#
#  33%|███▎      | 5/15 [00:14<00:29,  2.96s/it]
#
#
#
#
#  40%|████      | 6/15 [00:17<00:26,  2.90s/it]
#
#
#
#
#  47%|████▋     | 7/15 [00:20<00:22,  2.86s/it]
#
#
#
#
#  53%|█████▎    | 8/15 [00:23<00:19,  2.83s/it]
#
#
#
#
#  60%|██████    | 9/15 [00:25<00:16,  2.81s/it]
#
#
#
#
#  67%|██████▋   | 10/15 [00:28<00:13,  2.79s/it]
#
#
#
#
# ...

# %%
import os


second_path = 'video_data_475/v_Slipping_g20_c08/'
second_path_sub = os.listdir(second_path)
index = 1
for j in second_path_sub:
    os.renames(second_path + j, second_path + 'frame_' + str(index).zfill(6) + '.jpg')
    index += 1

# %%
run draw_fig.py
