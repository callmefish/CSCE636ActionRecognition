# %%
import os


first_dir = 'video_data_497_sim/'
first_dir_sub = os.listdir(first_dir)
first_dir_sub.sort()
print(len(first_dir_sub))
# Out:
# 468

# %%
import shutil

name = ['v_NotSlipping_g07_c03']
for i in first_dir_sub:
    second_dir = first_dir + i + '/'
    second_dir_sub = os.listdir(second_dir)
    if len(second_dir_sub) < 21:
        name.append(i)
        shutil.rmtree(first_dir + i)
print(name)
# Out:
# ['v_NotSlipping_g07_c03', 'v_NotSlipping_g09_c09', 'v_NotSlipping_g14_c10', 'v_NotSlipping_g21_c09', 'v_Slipping_g02_c05', 'v_Slipping_g03_c06', 'v_Slipping_g05_c08', 'v_Slipping_g05_c09', 'v_Slipping_g06_c10', 'v_Slipping_g07_c09', 'v_Slipping_g09_c01', 'v_Slipping_g09_c05', 'v_Slipping_g10_c03', 'v_Slipping_g10_c07', 'v_Slipping_g11_c02', 'v_Slipping_g11_c03', 'v_Slipping_g11_c06', 'v_Slipping_g12_c06', 'v_Slipping_g13_c06', 'v_Slipping_g14_c02', 'v_Slipping_g14_c07', 'v_Slipping_g14_c09', 'v_Slipping_g14_c10', 'v_Slipping_g15_c10', 'v_Slipping_g16_c01', 'v_Slipping_g16_c09', 'v_Slipping_g17_c05', 'v_Slipping_g19_c02', 'v_Slipping_g19_c08']

# %%
third_dir = 'opt/'
third_dir_sub = os.listdir(third_dir)
third_dir_sub.sort()
# for i in name[2:]:
#     u_path = third_dir + i + '_u'
#     shutil.rmtree(u_path)
#     v_path = third_dir + i + '_v'
#     shutil.rmtree(v_path)
print(len(third_dir_sub))
# Out:
# 936

# %%
run create_txt.py

# %%
run save_pickle.py

# %%
run motion_cnn.py
# Out:
# Namespace(batch_size=16, epochs=1, evaluate=False, lr=0.01, resume='', start_epoch=0)
# ==> (Training video, Validation video):( 351 117 )
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/csce636_project/project/motion_cnn.py in <module>
#     262
#     263 if __name__=='__main__':
# --> 264     main()
#
# ~/csce636_project/project/motion_cnn.py in main()
#      47                         )
#      48
# ---> 49     train_loader,test_loader, test_video = data_loader.run()
#      50     #Model
#      51     model = Motion_CNN(
#
# ~/csce636_project/project/dataloader/motion_dataloader.py in run(self)
#     101
#     102     def run(self):
# --> 103         self.load_frame_count()
#     104         self.get_training_dic()
#     105         self.val_sample19()
#
# ~/csce636_project/project/dataloader/motion_dataloader.py in load_frame_count(self)
# ...

# %%
run draw_fig.py

# %%
run average_fusion.py
# Out:
# ==> (Training video, Validation video):( 351 117 )
# ==> sampling testing frames
# ==> Training data : 3510 frames
# torch.Size([3, 224, 224])
# ==> Validation data : 2097 frames
# torch.Size([3, 224, 224])
# [tensor(67.5214)]

# %%
import os
print(os.path.exists('/home/yzy20161103/csce636_project/project/video_497_sim/v_NotSlipping_g02_c03/frame_000010.jpg'))
# Out:
# False

# %%
run whole_test.py
# Out:
# sample_video_05(N)
# 37.733333333333334
# ...
# 100%|██████████| 2/2 [00:00<00:00,  2.53it/s]
# not res , not image
# 100%|██████████| 2/2 [00:00<00:00,  2.56it/s]
# finish video analysis
# time_label : {'Slipping': [[0.0, 7.394274619281765e-06], [3.3333333333333335, 6.878262168391227e-06], [6.666666666666667, 0.004056867041205204], [10.0, 5.719701460936058e-05], [13.333333333333334, 1.1131858468082768e-07], [16.666666666666668, 9.860496124213391e-05], [20.0, 0.004946886683058638], [23.333333333333332, 0.00079824736377035], [26.666666666666668, 0.029958885200472067], [30.0, 0.002038312659224656], [33.333333333333336, 0.0003170872508469479], [36.7, 1.3575010674331663e-05]]}
